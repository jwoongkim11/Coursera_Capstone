# %% [markdown]
# # Introduction & Business Problem

# %% [markdown]
# In this project, I'll try to find the best location to open a cafe.
#
# The candidate locations are two universities in Seoul, Korea. One is around Sogang University and the other is around Korea university.
#
# When it comes to the location of cafe, the most important thing to consider is that it shouldn't be crowded with other cafes nearby.
#
# So my goal is finding the best location to open a cafe which is
#
# 1. Not so much crowded with other cafes nearby
# 2. Either around Sogang university or Korea university.

# %% [markdown]
# # Data

# %% [markdown]
# Datas that should be collected is as follows
#
# 1. Number of existing cafes in the neighborhood
# 2. Distance either from Sogang University or Korea university
# 3. Score based on the distance between existing cafes and its center location(Sogang university or Korea university)

# %% [markdown]
# # Methodology

# %% [markdown]
# 1. Get the latitude, longitude data of each locations
# 2. Search cafes nearby using foursquare
# 3. Calculate the number of cafes nearby as well as the distance from the ceter location
# 4. Calculate scores which represents the crowdedness of cafes in the area based on its distance from the center location
# 5. Choose the one with the lower score

# %% [markdown]
# Let's start off with the latitude and longitude of Sogang University.

# %%
from geopy.geocoders import Nominatim
def lat_lng(address):
    geolocator = Nominatim(user_agent = 'To_explorer')
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return [latitude, longitude]

Center_latlng = lat_lng('35 Baekbeom-ro, Daeheung-dong, Mapo-gu, Seoul')
print("Latitude, Longitude data is created!\n")
# Out:
# Latitude, Longitude data is created!

# %% [markdown]
# Let's define functions for creating distances from the center

# %%
import shapely.geometry
import pyproj
import math
import requests
import pandas as pd
import numpy as np
import random
from pandas.io.json import json_normalize

# %%
import utm
def lat_lng_to_xy(lat, lng):
    x, y, zone, ut = utm.from_latlon(lat, lng, force_zone_number = 52, force_zone_letter = 's')
    return x, y

def xy_to_lat_lng(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lat_lng = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lat_lng[0], lat_lng[1]

def xy_distance(x1,x2,y1,y2):
    delx = x2-x1
    dely = y2-y1
    return math.sqrt(delx*delx + dely*dely)

Sogang_x, Sogang_y = lat_lng_to_xy(Center_latlng[0], Center_latlng[1])
print('Sogang univ UTM is ({}, {})'.format(Sogang_x,Sogang_y))
# Out:
# Sogang univ UTM is (318119.7872306191, 4158114.2927324353)

# %% [markdown]
# The map around one of our candidate is...

# %%
import folium
map_Sogang = folium.Map(location=Center_latlng, zoom_start=13)
folium.Marker(location=Center_latlng, popup='Center').add_to(map_Sogang)
folium.Circle(Center_latlng, radius=1500, color='blue', fill=False).add_to(map_Sogang)
map_Sogang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's get some information of cafes around the area
#
# I'll use Foursquare datas for this

# %%
CLIENT_ID = '2OFQNQUE1KNXITHBRLENLT0JNBBZUSWISREFXMRWYTS1Q5AW'
CLIENT_SECRET = '1G5XGH3HF0C2U4KLKBFAEEH0IZUAVBYOLPENKIKQ0IDOQA2P'
VERSION = '20200301'
LIMIT = 1000
print('CLIENT ID : ' + CLIENT_ID)
print('CLIENT SECRET : ' + CLIENT_SECRET)
# Out:
# CLIENT ID : 2OFQNQUE1KNXITHBRLENLT0JNBBZUSWISREFXMRWYTS1Q5AW
# CLIENT SECRET : 1G5XGH3HF0C2U4KLKBFAEEH0IZUAVBYOLPENKIKQ0IDOQA2P

# %%
address = '35 Baekbeom-ro, Daeheung-dong, Mapo-gu, Seoul'
geolocator = Nominatim(user_agent = 'foursquare_agent')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
search_query = 'Cafe'
radius = 1500
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e6a1935e826ac001bd8c48a'},
#  'response': {'venues': [{'id': '4e5efed218a870f60f3440f1',
#     'name': 'Sogang University Matthew Hall International Cafe (서강대학교 마태오관 International Cafe)',
#     'location': {'address': '마포구 백범로 35 3층',
#      'lat': 37.552265936937594,
#      'lng': 126.93932030540398,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.552265936937594,
#        'lng': 126.93932030540398}],
#      'distance': 147,
#      'postalCode': '04107',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 백범로 35 3층',
#       '대흥동',
#       '서울특별시',
#       '서울특별시',
#       '04107',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4da5639d0cb6d75e29f6b81d',
#     'name': 'Cafe Risio (카페 오프네)',
#     'location': {'lat': 37.550886,
#      'lng': 126.943234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.550886,
#        'lng': 126.943234}],
#      'distance': 240,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['대흥동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4e9154780aafb4070c48d930',
#     'name': 'A to Z cafe',
#     'location': {'address': '서대문구 연세로4길 30',
#      'lat': 37.557597626791754,
#      'lng': 126.93841492266895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.557597626791754,
#        'lng': 126.93841492266895}],
#      'distance': 652,
#      'postalCode': '120-833',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 연세로4길 30',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-833',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4b982966f964a5209a3035e3',
#     'name': 'Food Cafe 김밥천국',
#     'location': {'address': '서대문구 신촌역로 19-2',
#      'crossStreet': '신촌로터리',
#      'lat': 37.55853003754897,
#      'lng': 126.94272671227723,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55853003754897,
#        'lng': 126.94272671227723}],
#      'distance': 731,
#      'postalCode': '120-809',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 신촌역로 19-2 (신촌로터리)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-809',
#       '대한민국']},
#     'categories': [{'id': '56aa371be4b08b9a8d5734f0',
#       'name': 'Bunsik Restaurant',
#       'pluralName': 'Bunsik Restaurants',
#       'shortName': 'Bunsik',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4d6da6f630d5b1f73449bc42',
#     'name': '잡카페 Job Cafe',
#     'location': {'lat': 37.55056493189287,
#      'lng': 126.94003412603388,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55056493189287,
#        'lng': 126.94003412603388}],
#      'distance': 190,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['대흥동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '50753c8de4b0c8feb2112189',
#     'name': 'Cafe Noriter (지구별 고양이 (카페 노리터))',
#     'location': {'address': '서대문구 이화여대1안길 9 2, 3층',
#      'crossStreet': '이대점',
#      'lat': 37.55765839181192,
#      'lng': 126.94463818352155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55765839181192,
#        'lng': 126.94463818352155}],
#      'distance': 697,
#      'postalCode': '03766',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 이화여대1안길 9 2, 3층 (이대점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '03766',
#       '대한민국']},
#     'categories': [{'id': '56aa371be4b08b9a8d573508',
#       'name': 'Pet Café',
#       'pluralName': 'Pet Cafés',
#       'shortName': 'Pet Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4b9a3498f964a5206fa435e3',
#     'name': 'cafe Suッkara (수카라) (수카라)',
#     'location': {'address': '마포구 와우산로 157',
#      'lat': 37.55502278444561,
#      'lng': 126.93014502525331,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55502278444561,
#        'lng': 126.93014502525331}],
#      'distance': 1010,
#      'postalCode': '04052',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 와우산로 157',
#       '서교동',
#       '마포구',
#       '서울특별시',
#       '04052',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4ca55304d971b1f7f504f6e0',
#     'name': '서강대학교 Cafe KKINI',
#     'location': {'address': '마포구 신수동 서강대학교 곤자가플라자',
#      'lat': 37.55084546318485,
#      'lng': 126.943452113808,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55084546318485,
#        'lng': 126.943452113808}],
#      'distance': 259,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 신수동 서강대학교 곤자가플라자',
#       '대흥동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4c7e0a5fb53db1f757e29e11',
#     'name': 'Cafe Calling (카페 콜링) (카페 콜링)',
#     'location': {'address': '마포구 대흥로21길 4',
#      'lat': 37.553477,
#      'lng': 126.945598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.553477,
#        'lng': 126.945598}],
#      'distance': 434,
#      'postalCode': '04106',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 대흥로21길 4',
#       '대흥동',
#       '서울특별시',
#       '서울특별시',
#       '04106',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '50113732e4b0c3490cf8c245',
#     'name': 'Chak Han Pig Self Cafe (착한돼지)',
#     'location': {'address': '서대문구 명물길 40',
#      'crossStreet': '신촌점',
#      'lat': 37.558506124614304,
#      'lng': 126.93879191212126,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.558506124614304,
#        'lng': 126.93879191212126}],
#      'distance': 738,
#      'cc': 'KR',
#      'neighborhood': '창천동',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 명물길 40 (신촌점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4fe0575ee4b02857f0b7a694',
#     'name': 'cafe italico',
#     'location': {'lat': 37.54776002517562,
#      'lng': 126.94224377665718,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.54776002517562,
#        'lng': 126.94224377665718}],
#      'distance': 496,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['대흥동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '51bc3b3f498e1757e856245d',
#     'name': 'CAFE 혜민정',
#     'location': {'address': '마포구 숭문길 108',
#      'lat': 37.551162,
#      'lng': 126.946606,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.551162,
#        'lng': 126.946606}],
#      'distance': 507,
#      'cc': 'KR',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 숭문길 108', '염리동', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4bf1fea178cec9289617bb86',
#     'name': 'PARIS BAGUETTE Café',
#     'location': {'address': '서대문구 연세로4길 1',
#      'crossStreet': '신촌점',
#      'lat': 37.557015071505255,
#      'lng': 126.93695791903306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.557015071505255,
#        'lng': 126.93695791903306}],
#      'distance': 651,
#      'postalCode': '120-833',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 연세로4길 1 (신촌점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-833',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '5b7cddcfdab4b1002b13d36d',
#     'name': 'Brunch Cafe 37.5 Express',
#     'location': {'address': '마포구 마포대로11길 44-19',
#      'crossStreet': '공덕직영점',
#      'lat': 37.549824,
#      'lng': 126.952332,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.549824,
#        'lng': 126.952332}],
#      'distance': 1033,
#      'postalCode': '04132',
#      'cc': 'KR',
#      'neighborhood': '공덕동',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 마포대로11길 44-19 (공덕직영점)',
#       '아현동',
#       '서울특별시',
#       '04132',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4e0fee9b62e1d997a692f3e5',
#     'name': 'cafe 하루',
#     'location': {'address': '서대문구 신촌로 89',
#      'lat': 37.5553312528549,
#      'lng': 126.93595580711613,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5553312528549,
#        'lng': 126.93595580711613}],
#      'distance': 570,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 신촌로 89', '서교동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '5211a40f11d24231a48cde3c',
#     'name': 'Cafe Gabie (가비애)',
#     'location': {'address': '마포구 와우산로 147-1',
#      'lat': 37.5544921076475,
#      'lng': 126.92965116338623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5544921076475,
#        'lng': 126.92965116338623}],
#      'distance': 1034,
#      'postalCode': '04053',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 와우산로 147-1',
#       '서교동',
#       '서울특별시',
#       '서울특별시',
#       '04053',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '57021bd9498eb04614873004',
#     'name': 'CAFE ROOMING (CAFE 루밍)',
#     'location': {'address': '서대문구 명물길 10 5F',
#      'lat': 37.55677772543982,
#      'lng': 126.93818657598129,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55677772543982,
#        'lng': 126.93818657598129}],
#      'distance': 575,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 명물길 10 5F', '신촌동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4e197dcf14957dc705e18647',
#     'name': 'Café Trinitea (카페 트리니티)',
#     'location': {'address': '서대문구 신촌로 157-8',
#      'crossStreet': '이대1호점',
#      'lat': 37.55718161851756,
#      'lng': 126.94358517859051,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55718161851756,
#        'lng': 126.94358517859051}],
#      'distance': 610,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 신촌로 157-8 (이대1호점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '5811c1de38faec4196b60196',
#     'name': 'Cafe De Paris (카페드파리)',
#     'location': {'address': '마포구 와우산로27길 43',
#      'crossStreet': '홍대점',
#      'lat': 37.55479145919985,
#      'lng': 126.92611446014789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55479145919985,
#        'lng': 126.92611446014789}],
#      'distance': 1345,
#      'postalCode': '04054',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 와우산로27길 43 (홍대점)',
#       '서교동',
#       '서울특별시',
#       '서울특별시',
#       '04054',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4e3d3d2eb61cb577be740724',
#     'name': 'cafe 7gram',
#     'location': {'address': '서대문구 신촌로 171',
#      'crossStreet': '이대점',
#      'lat': 37.55682593567337,
#      'lng': 126.94506693589314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55682593567337,
#        'lng': 126.94506693589314}],
#      'distance': 637,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 신촌로 171 (이대점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '57ebba79498ec263bf01cb35',
#     'name': 'YOUR CAFE in YOUR GYM',
#     'location': {'address': '르메이에르 5차빌딩 지하4층',
#      'crossStreet': '신촌로 109',
#      'lat': 37.555862,
#      'lng': 126.938224,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.555862,
#        'lng': 126.938224}],
#      'distance': 484,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['르메이에르 5차빌딩 지하4층 (신촌로 109)',
#       '신촌동',
#       '서대문구',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '51ceb047498ec2e45b4332d8',
#     'name': 'café de Comics (카페데코믹스)',
#     'location': {'address': '서대문구 연세로4길 27',
#      'crossStreet': '신촌점',
#      'lat': 37.557513549713754,
#      'lng': 126.93817082961571,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.557513549713754,
#        'lng': 126.93817082961571}],
#      'distance': 651,
#      'postalCode': '120-833',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 연세로4길 27 (신촌점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-833',
#       '대한민국']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b18',
#       'name': 'Comic Shop',
#       'pluralName': 'Comic Shops',
#       'shortName': 'Comic Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4b8a3152f964a5208c6332e3',
#     'name': 'PARIS BAGUETTE Café',
#     'location': {'address': '마포구 백범로 98-1',
#      'crossStreet': '대흥역점',
#      'lat': 37.547601368088905,
#      'lng': 126.94232775256245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.547601368088905,
#        'lng': 126.94232775256245}],
#      'distance': 515,
#      'postalCode': '121-809',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 백범로 98-1 (대흥역점)',
#       '대흥동',
#       '서울특별시',
#       '서울특별시',
#       '121-809',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4e01bfe3d22db37fb02900d1',
#     'name': 'Café poem',
#     'location': {'lat': 37.55797611971428,
#      'lng': 126.9369467792323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55797611971428,
#        'lng': 126.9369467792323}],
#      'distance': 744,
#      'postalCode': '120-833',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['신촌동', '서울특별시', '서울특별시', '120-833', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4fc1a252e4b099ce1739d50a',
#     'name': 'Cafe 7gram',
#     'location': {'address': '서대문구 명물길26',
#      'crossStreet': '신촌점',
#      'lat': 37.5580316738042,
#      'lng': 126.93800811697304,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5580316738042,
#        'lng': 126.93800811697304}],
#      'distance': 710,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 명물길26 (신촌점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '55a78902498ee1734ee7acf4',
#     'name': 'cafe blog 이대점',
#     'location': {'lat': 37.557485,
#      'lng': 126.946107,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.557485,
#        'lng': 126.946107}],
#      'distance': 750,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['신촌동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '56c3c739cd101cd7cb1300c9',
#     'name': 'CAFE GATE (카페게이트)',
#     'location': {'lat': 37.55862631489004,
#      'lng': 126.9399239041851,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55862631489004,
#        'lng': 126.9399239041851}],
#      'distance': 732,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['신촌동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4cce7c44c9b84688cce3c8c3',
#     'name': 'Cafe de Heba',
#     'location': {'address': '서대문구',
#      'lat': 37.55799940474078,
#      'lng': 126.94519337258788,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55799940474078,
#        'lng': 126.94519337258788}],
#      'distance': 754,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구', '신촌동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4bd67311637ba5930f4bf870',
#     'name': 'cafe coi',
#     'location': {'address': '서대문구 연세로7안길 10-4',
#      'lat': 37.55832804687838,
#      'lng': 126.93641318809863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55832804687838,
#        'lng': 126.93641318809863}],
#      'distance': 801,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 연세로7안길 10-4',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4cc2b3a53d7fa1cd2b8ea05f',
#     'name': 'Cafe Artigiano (카페 아띠지아노)',
#     'location': {'address': '서대문구 이화여대2가길 12',
#      'crossStreet': '이대점',
#      'lat': 37.55803511025693,
#      'lng': 126.94603829640074,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55803511025693,
#        'lng': 126.94603829640074}],
#      'distance': 796,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 이화여대2가길 12 (이대점)',
#       '신촌동',
#       '서대문구',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4d9ae4659298b1f77d744a38',
#     'name': 'cafe Pera (카페페라)',
#     'location': {'address': '서대문구 이화여대8길 2',
#      'crossStreet': '본점',
#      'lat': 37.558745903136895,
#      'lng': 126.94594775638461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.558745903136895,
#        'lng': 126.94594775638461}],
#      'distance': 859,
#      'postalCode': '03767',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 이화여대8길 2 (본점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '03767',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4d9aeb063f785481e3abd3d1',
#     'name': '카페 라파스 Cafe lapaz',
#     'location': {'address': '서대문구 이화여대1길 46',
#      'lat': 37.55753149504499,
#      'lng': 126.94391802808009,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55753149504499,
#        'lng': 126.94391802808009}],
#      'distance': 657,
#      'postalCode': '120-809',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 이화여대1길 46',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-809',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4cd65484886cb60c0f888989',
#     'name': 'cafe 달',
#     'location': {'address': '서울시 서대문구 창천동',
#      'lat': 37.55851153311685,
#      'lng': 126.93537842057438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55851153311685,
#        'lng': 126.93537842057438}],
#      'distance': 867,
#      'postalCode': '120-834',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서울시 서대문구 창천동',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-834',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '51d5117e498ec882707a4b4d',
#     'name': 'Uptown Cafe (업타운카페)',
#     'location': {'address': '서대문구 연세로 50-1',
#      'crossStreet': '신촌세브란스점',
#      'lat': 37.56229234813374,
#      'lng': 126.94055902786374,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.56229234813374,
#        'lng': 126.94055902786374}],
#      'distance': 1134,
#      'postalCode': '03722',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 연세로 50-1 (신촌세브란스점)',
#       '신촌동',
#       '서대문구',
#       '서울특별시',
#       '03722',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4db287b54b220b5fbb043b70',
#     'name': 'Cat Cafe',
#     'location': {'crossStreet': '신촌점',
#      'lat': 37.558316,
#      'lng': 126.936748,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.558316,
#        'lng': 126.936748}],
#      'distance': 786,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['신촌점', '신촌동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4b6e7161f964a520a4bd2ce3',
#     'name': 'Thanks Nature Cafe',
#     'location': {'address': '마포구 홍익로 10',
#      'lat': 37.553382093191225,
#      'lng': 126.92374318477684,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.553382093191225,
#        'lng': 126.92374318477684}],
#      'distance': 1528,
#      'postalCode': '121-837',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 홍익로 10',
#       '서교동',
#       '서울특별시',
#       '서울특별시',
#       '121-837',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '5041e031e4b07118808dfdb1',
#     'name': '치킨 Cafe 뽈로',
#     'location': {'lat': 37.55731914473391,
#      'lng': 126.93560412676449,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55731914473391,
#        'lng': 126.93560412676449}],
#      'distance': 749,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['신촌동', '대한민국']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '500f97d8e4b0b1bc5e3caceb',
#     'name': 'POP.CON.TAINER Cafe (팝컨테이너 카페)',
#     'location': {'address': '서대문구 명물길 70 2F',
#      'crossStreet': '신촌',
#      'lat': 37.559076971778296,
#      'lng': 126.94010223643463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.559076971778296,
#        'lng': 126.94010223643463}],
#      'distance': 780,
#      'postalCode': '120-833',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 명물길 70 2F (신촌)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-833',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4c565646cc96c9b638a1762e',
#     'name': 'Cafe Cantata (카페칸타타)',
#     'location': {'address': '서대문구 이화여대길 48',
#      'crossStreet': '이대점',
#      'lat': 37.55930107325993,
#      'lng': 126.94571662473902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55930107325993,
#        'lng': 126.94571662473902}],
#      'distance': 903,
#      'postalCode': '03764',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 이화여대길 48 (이대점)',
#       '신촌동',
#       '서대문구',
#       '서울특별시',
#       '03764',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4bc99af6937ca593d704a692',
#     'name': 'Manoffin g-Cafe',
#     'location': {'lat': 37.55866390008492,
#      'lng': 126.94602259701142,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55866390008492,
#        'lng': 126.94602259701142}],
#      'distance': 854,
#      'postalCode': '120-808',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['신촌동', '서울특별시', '서울특별시', '120-808', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1bc941735',
#       'name': 'Cupcake Shop',
#       'pluralName': 'Cupcake Shops',
#       'shortName': 'Cupcakes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '5de25f04a191b90008eb9c4a',
#     'name': 'Cafe Arcade (카페 아케이드)',
#     'location': {'address': '23',
#      'crossStreet': 'Hongik-ro',
#      'lat': 37.55436,
#      'lng': 126.92217,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55436,
#        'lng': 126.92217}],
#      'distance': 1679,
#      'postalCode': '04039',
#      'cc': 'KR',
#      'neighborhood': 'Seogyo-dong',
#      'city': '마포구',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['23 (Hongik-ro)',
#       '서교동',
#       '마포구',
#       '서울특별시',
#       '04039',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '54f1594e498ef9bd207b8478',
#     'name': 'cafe bonjur (카페 본주르)',
#     'location': {'address': '마포구 양화로21길 23',
#      'lat': 37.55932967937358,
#      'lng': 126.92491208169993,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55932967937358,
#        'lng': 126.92491208169993}],
#      'distance': 1630,
#      'postalCode': '121-816',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 양화로21길 23',
#       '서교동',
#       '서울특별시',
#       '서울특별시',
#       '121-816',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4e81473bdab498c614e96e6a',
#     'name': 'Cafe Bridge (카페 브릿지)',
#     'location': {'lat': 37.55543183138664,
#      'lng': 126.92503562105472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55543183138664,
#        'lng': 126.92503562105472}],
#      'distance': 1455,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서교동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4d6f2c083599370459080a9d',
#     'name': 'Cafe JINNN',
#     'location': {'address': '서대문구 성산로22길 4',
#      'lat': 37.56056434573329,
#      'lng': 126.93363048629404,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.56056434573329,
#        'lng': 126.93363048629404}],
#      'distance': 1143,
#      'postalCode': '120-835',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 성산로22길 4',
#       '연희동',
#       '서울특별시',
#       '서울특별시',
#       '120-835',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '50c1d4c0e4b07236438c8ace',
#     'name': 'café monobloc (모노블록)',
#     'location': {'address': '마포구 와우산로23길 14',
#      'lat': 37.55375387464724,
#      'lng': 126.92436860594569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55375387464724,
#        'lng': 126.92436860594569}],
#      'distance': 1477,
#      'postalCode': '121-837',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 와우산로23길 14',
#       '서교동',
#       '서울특별시',
#       '서울특별시',
#       '121-837',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '50001310e4b0e08eeeb2fbfa',
#     'name': 'Cafe Vine',
#     'location': {'address': '서대문구 신촌로 25',
#      'crossStreet': '홍대점',
#      'lat': 37.55778313002837,
#      'lng': 126.92948895453995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55778313002837,
#        'lng': 126.92948895453995}],
#      'distance': 1195,
#      'postalCode': '120-836',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 신촌로 25 (홍대점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-836',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '52902cbe11d22f9fcc401aa4',
#     'name': 'Cafe URP classic',
#     'location': {'address': '마포구 연희로 7',
#      'lat': 37.55948237452359,
#      'lng': 126.92676957231778,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55948237452359,
#        'lng': 126.92676957231778}],
#      'distance': 1499,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 연희로 7', '신촌동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '50220736e4b05f49ad9abe09',
#     'name': 'cafe十月',
#     'location': {'lat': 37.55457895114744,
#      'lng': 126.92763050266777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.55457895114744,
#        'lng': 126.92763050266777}],
#      'distance': 1210,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['서교동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '59554384b9a5a80f8303d367',
#     'name': 'Cafe Hey, Lin (카페헤이린)',
#     'location': {'address': '마포구 와우산로29다길 10',
#      'lat': 37.555084,
#      'lng': 126.92763,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.555084,
#        'lng': 126.92763}],
#      'distance': 1224,
#      'postalCode': '04053',
#      'cc': 'KR',
#      'neighborhood': '서교동',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['마포구 와우산로29다길 10',
#       '서교동',
#       '마포구',
#       '서울특별시',
#       '04053',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False},
#    {'id': '4d75e3578d7e236a81cbaf28',
#     'name': 'CNN Café',
#     'location': {'address': '서대문구 이화여대길 52 국제교육관 1층',
#      'crossStreet': '이화여대점',
#      'lat': 37.56032590732792,
#      'lng': 126.94405973412287,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.56032590732792,
#        'lng': 126.94405973412287}],
#      'distance': 954,
#      'postalCode': '120-750',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서대문구 이화여대길 52 국제교육관 1층 (이화여대점)',
#       '신촌동',
#       '서울특별시',
#       '서울특별시',
#       '120-750',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584011717',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
sogang = json_normalize(venues)
sogang.head()
# Out:
# <ipython-input-295-ff44d0c40799>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   sogang = json_normalize(venues)
#                          id  \
# 0  4e5efed218a870f60f3440f1
# 1  4da5639d0cb6d75e29f6b81d
# 2  4e9154780aafb4070c48d930
# 3  4b982966f964a5209a3035e3
# 4  4d6da6f630d5b1f73449bc42
#
#                                                 name  \
# 0  Sogang University Matthew Hall International C...
# 1                                Cafe Risio (카페 오프네)
# 2                                        A to Z cafe
# 3                                     Food Cafe 김밥천국
# 4                                       잡카페 Job Cafe
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1584011717    False
# 1                                                 []  v-1584011717    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1584011717    False
# 3  [{'id': '56aa371be4b08b9a8d5734f0', 'name': 'B...  v-1584011717    False
# 4                                                 []  v-1584011717    False
#
#   location.address  location.lat  location.lng  \
# 0    마포구 백범로 35 3층     37.552266    126.939320
# 1              NaN     37.550886    126.943234
# 2    서대문구 연세로4길 30     37.557598    126.938415
# 3   서대문구 신촌역로 19-2     37.558530    126.942727
# 4              NaN     37.550565    126.940034
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 37.55226593693759...                147
# 1  [{'label': 'display', 'lat': 37.550886, 'lng':...                240
# 2  [{'label': 'display', 'lat': 37.55759762679175...                652
# 3  [{'label': 'display', 'lat': 37.55853003754897...                731
# 4  [{'label': 'display', 'lat': 37.55056493189287...                190
#
#   location.postalCode location.cc location.city location.state  \
# 0               04107          KR         서울특별시          서울특별시
# 1                 NaN          KR         서울특별시          서울특별시
# 2             120-833          KR         서울특별시          서울특별시
# 3             120-809          KR         서울특별시          서울특별시
# 4                 NaN          KR         서울특별시          서울특별시
#
#   location.country                          location.formattedAddress  \
# 0             대한민국    [마포구 백범로 35 3층, 대흥동, 서울특별시, 서울특별시, 04107, 대한민국]
# 1             대한민국                          [대흥동, 서울특별시, 서울특별시, 대한민국]
# 2             대한민국  [서대문구 연세로4길 30, 신촌동, 서울특별시, 서울특별시, 120-833, 대한민국]
# 3             대한민국  [서대문구 신촌역로 19-2 (신촌로터리), 신촌동, 서울특별시, 서울특별시, 12...
# 4             대한민국                          [대흥동, 서울특별시, 서울특별시, 대한민국]
#
#   location.crossStreet location.neighborhood
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                신촌로터리                   NaN
# 4                  NaN                   NaN

# %%
#Drop any colums without its name starting with 'location'
sogang_columns = ['name', 'categories'] + [col for col in sogang.columns if col.startswith('location.')] + ['id']
sogang_filtered = sogang.loc[:, filtered_columns]

#Cleaning category column 
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']


sogang_filtered['categories'] = sogang_filtered.apply(get_category_type, axis=1)

#Clean column names with only last term
sogang_filtered.columns = [column.split('.')[-1] for column in sogang_filtered.columns]
sogang_filtered
# Out:
#                                                  name           categories  \
# 0   Sogang University Matthew Hall International C...                 Café
# 1                                 Cafe Risio (카페 오프네)                 None
# 2                                         A to Z cafe          Coffee Shop
# 3                                      Food Cafe 김밥천국    Bunsik Restaurant
# 4                                        잡카페 Job Cafe                 None
# 5                     Cafe Noriter (지구별 고양이 (카페 노리터))             Pet Café
# 6                            cafe Suッkara (수카라) (수카라)                 Café
# 7                                    서강대학교 Cafe KKINI   Italian Restaurant
# 8                        Cafe Calling (카페 콜링) (카페 콜링)                 Café
# 9                       Chak Han Pig Self Cafe (착한돼지)            BBQ Joint
# 10                                       cafe italico                 Café
# 11                                           CAFE 혜민정                 Café
# 12                                PARIS BAGUETTE Café               Bakery
# 13                           Brunch Cafe 37.5 Express       Breakfast Spot
# 14                                            cafe 하루                 Café
# 15                                   Cafe Gabie (가비애)          Coffee Shop
# 16                             CAFE ROOMING (CAFE 루밍)                 Café
# 17                            Café Trinitea (카페 트리니티)                 Café
# 18                              Cafe De Paris (카페드파리)                 Café
# 19                                         cafe 7gram                 Café
# 20                              YOUR CAFE in YOUR GYM                 Café
# 21                            café de Comics (카페데코믹스)           Comic Shop
# 22                                PARIS BAGUETTE Café               Bakery
# 23                                          Café poem                 Café
# 24                                         Cafe 7gram          Coffee Shop
# 25                                      cafe blog 이대점                 Café
# 26                                  CAFE GATE (카페게이트)          Coffee Shop
# 27                                       Cafe de Heba                 Café
# 28                                           cafe coi                 Café
# 29                          Cafe Artigiano (카페 아띠지아노)               Bakery
# 30                                   cafe Pera (카페페라)         Dessert Shop
# 31                                  카페 라파스 Cafe lapaz          Coffee Shop
# 32                                             cafe 달                  Bar
# 33                                Uptown Cafe (업타운카페)                 Café
# 34                                           Cat Cafe                 Café
# 35                                 Thanks Nature Cafe          Coffee Shop
# 36                                         치킨 Cafe 뽈로  Fried Chicken Joint
# 37                     POP.CON.TAINER Cafe (팝컨테이너 카페)                 Café
# 38                               Cafe Cantata (카페칸타타)          Coffee Shop
# 39                                    Manoffin g-Cafe         Cupcake Shop
# 40                              Cafe Arcade (카페 아케이드)                 Café
# 41                               cafe bonjur (카페 본주르)          Coffee Shop
# 42                               Cafe Bridge (카페 브릿지)                 Café
# 43                                         Cafe JINNN                 Café
# 44                               café monobloc (모노블록)                 Café
# 45                                          Cafe Vine          Coffee Shop
# 46                                   Cafe URP classic          Coffee Shop
# 47                                             cafe十月                 Café
# 48                              Cafe Hey, Lin (카페헤이린)         Dessert Shop
# 49                                           CNN Café          Coffee Shop
#
#                    address        lat         lng  \
# 0            마포구 백범로 35 3층  37.552266  126.939320
# 1                      NaN  37.550886  126.943234
# 2            서대문구 연세로4길 30  37.557598  126.938415
# 3           서대문구 신촌역로 19-2  37.558530  126.942727
# 4                      NaN  37.550565  126.940034
# 5     서대문구 이화여대1안길 9 2, 3층  37.557658  126.944638
# 6             마포구 와우산로 157  37.555023  126.930145
# 7     마포구 신수동 서강대학교 곤자가플라자  37.550845  126.943452
# 8             마포구 대흥로21길 4  37.553477  126.945598
# 9              서대문구 명물길 40  37.558506  126.938792
# 10                     NaN  37.547760  126.942244
# 11             마포구 숭문길 108  37.551162  126.946606
# 12            서대문구 연세로4길 1  37.557015  126.936958
# 13       마포구 마포대로11길 44-19  37.549824  126.952332
# 14             서대문구 신촌로 89  37.555331  126.935956
# 15          마포구 와우산로 147-1  37.554492  126.929651
# 16          서대문구 명물길 10 5F  37.556778  126.938187
# 17          서대문구 신촌로 157-8  37.557182  126.943585
# 18          마포구 와우산로27길 43  37.554791  126.926114
# 19            서대문구 신촌로 171  37.556826  126.945067
# 20         르메이에르 5차빌딩 지하4층  37.555862  126.938224
# 21           서대문구 연세로4길 27  37.557514  126.938171
# 22            마포구 백범로 98-1  37.547601  126.942328
# 23                     NaN  37.557976  126.936947
# 24              서대문구 명물길26  37.558032  126.938008
# 25                     NaN  37.557485  126.946107
# 26                     NaN  37.558626  126.939924
# 27                    서대문구  37.557999  126.945193
# 28        서대문구 연세로7안길 10-4  37.558328  126.936413
# 29         서대문구 이화여대2가길 12  37.558035  126.946038
# 30           서대문구 이화여대8길 2  37.558746  126.945948
# 31          서대문구 이화여대1길 46  37.557531  126.943918
# 32            서울시 서대문구 창천동  37.558512  126.935378
# 33           서대문구 연세로 50-1  37.562292  126.940559
# 34                     NaN  37.558316  126.936748
# 35              마포구 홍익로 10  37.553382  126.923743
# 36                     NaN  37.557319  126.935604
# 37          서대문구 명물길 70 2F  37.559077  126.940102
# 38           서대문구 이화여대길 48  37.559301  126.945717
# 39                     NaN  37.558664  126.946023
# 40                      23  37.554360  126.922170
# 41           마포구 양화로21길 23  37.559330  126.924912
# 42                     NaN  37.555432  126.925036
# 43           서대문구 성산로22길 4  37.560564  126.933630
# 44          마포구 와우산로23길 14  37.553754  126.924369
# 45             서대문구 신촌로 25  37.557783  126.929489
# 46               마포구 연희로 7  37.559482  126.926770
# 47                     NaN  37.554579  126.927631
# 48         마포구 와우산로29다길 10  37.555084  126.927630
# 49  서대문구 이화여대길 52 국제교육관 1층  37.560326  126.944060
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 37.55226593693759...       147      04107
# 1   [{'label': 'display', 'lat': 37.550886, 'lng':...       240        NaN
# 2   [{'label': 'display', 'lat': 37.55759762679175...       652    120-833
# 3   [{'label': 'display', 'lat': 37.55853003754897...       731    120-809
# 4   [{'label': 'display', 'lat': 37.55056493189287...       190        NaN
# 5   [{'label': 'display', 'lat': 37.55765839181192...       697      03766
# 6   [{'label': 'display', 'lat': 37.55502278444561...      1010      04052
# 7   [{'label': 'display', 'lat': 37.55084546318485...       259        NaN
# 8   [{'label': 'display', 'lat': 37.553477, 'lng':...       434      04106
# 9   [{'label': 'display', 'lat': 37.55850612461430...       738        NaN
# 10  [{'label': 'display', 'lat': 37.54776002517562...       496        NaN
# 11  [{'label': 'display', 'lat': 37.551162, 'lng':...       507        NaN
# 12  [{'label': 'display', 'lat': 37.55701507150525...       651    120-833
# 13  [{'label': 'display', 'lat': 37.549824, 'lng':...      1033      04132
# 14  [{'label': 'display', 'lat': 37.5553312528549,...       570        NaN
# 15  [{'label': 'display', 'lat': 37.5544921076475,...      1034      04053
# 16  [{'label': 'display', 'lat': 37.55677772543982...       575        NaN
# 17  [{'label': 'display', 'lat': 37.55718161851756...       610        NaN
# 18  [{'label': 'display', 'lat': 37.55479145919985...      1345      04054
# 19  [{'label': 'display', 'lat': 37.55682593567337...       637        NaN
# 20  [{'label': 'display', 'lat': 37.555862, 'lng':...       484        NaN
# 21  [{'label': 'display', 'lat': 37.55751354971375...       651    120-833
# 22  [{'label': 'display', 'lat': 37.54760136808890...       515    121-809
# 23  [{'label': 'display', 'lat': 37.55797611971428...       744    120-833
# 24  [{'label': 'display', 'lat': 37.5580316738042,...       710        NaN
# 25  [{'label': 'display', 'lat': 37.557485, 'lng':...       750        NaN
# 26  [{'label': 'display', 'lat': 37.55862631489004...       732        NaN
# 27  [{'label': 'display', 'lat': 37.55799940474078...       754        NaN
# 28  [{'label': 'display', 'lat': 37.55832804687838...       801        NaN
# 29  [{'label': 'display', 'lat': 37.55803511025693...       796        NaN
# 30  [{'label': 'display', 'lat': 37.55874590313689...       859      03767
# 31  [{'label': 'display', 'lat': 37.55753149504499...       657    120-809
# 32  [{'label': 'display', 'lat': 37.55851153311685...       867    120-834
# 33  [{'label': 'display', 'lat': 37.56229234813374...      1134      03722
# 34  [{'label': 'display', 'lat': 37.558316, 'lng':...       786        NaN
# 35  [{'label': 'display', 'lat': 37.55338209319122...      1528    121-837
# 36  [{'label': 'display', 'lat': 37.55731914473391...       749        NaN
# 37  [{'label': 'display', 'lat': 37.55907697177829...       780    120-833
# 38  [{'label': 'display', 'lat': 37.55930107325993...       903      03764
# 39  [{'label': 'display', 'lat': 37.55866390008492...       854    120-808
# 40  [{'label': 'display', 'lat': 37.55436, 'lng': ...      1679      04039
# 41  [{'label': 'display', 'lat': 37.55932967937358...      1630    121-816
# 42  [{'label': 'display', 'lat': 37.55543183138664...      1455        NaN
# 43  [{'label': 'display', 'lat': 37.56056434573329...      1143    120-835
# 44  [{'label': 'display', 'lat': 37.55375387464724...      1477    121-837
# 45  [{'label': 'display', 'lat': 37.55778313002837...      1195    120-836
# 46  [{'label': 'display', 'lat': 37.55948237452359...      1499        NaN
# 47  [{'label': 'display', 'lat': 37.55457895114744...      1210        NaN
# 48  [{'label': 'display', 'lat': 37.555084, 'lng':...      1224      04053
# 49  [{'label': 'display', 'lat': 37.56032590732792...       954    120-750
#
#     cc   city  state country  \
# 0   KR  서울특별시  서울특별시    대한민국
# 1   KR  서울특별시  서울특별시    대한민국
# 2   KR  서울특별시  서울특별시    대한민국
# 3   KR  서울특별시  서울특별시    대한민국
# 4   KR  서울특별시  서울특별시    대한민국
# 5   KR  서울특별시  서울특별시    대한민국
# 6   KR  서울특별시  서울특별시    대한민국
# 7   KR  서울특별시  서울특별시    대한민국
# 8   KR  서울특별시  서울특별시    대한민국
# 9   KR  서울특별시  서울특별시    대한민국
# 10  KR  서울특별시  서울특별시    대한민국
# 11  KR    NaN  서울특별시    대한민국
# 12  KR  서울특별시  서울특별시    대한민국
# 13  KR    NaN  서울특별시    대한민국
# 14  KR  서울특별시  서울특별시    대한민국
# 15  KR  서울특별시  서울특별시    대한민국
# 16  KR  서울특별시  서울특별시    대한민국
# 17  KR  서울특별시  서울특별시    대한민국
# 18  KR  서울특별시  서울특별시    대한민국
# 19  KR  서울특별시  서울특별시    대한민국
# 20  KR  서울특별시  서울특별시    대한민국
# 21  KR  서울특별시  서울특별시    대한민국
# 22  KR  서울특별시  서울특별시    대한민국
# 23  KR  서울특별시  서울특별시    대한민국
# 24  KR  서울특별시  서울특별시    대한민국
# 25  KR    NaN    NaN    대한민국
# 26  KR    NaN    NaN    대한민국
# 27  KR  서울특별시  서울특별시    대한민국
# 28  KR  서울특별시  서울특별시    대한민국
# 29  KR  서울특별시  서울특별시    대한민국
# 30  KR  서울특별시  서울특별시    대한민국
# 31  KR  서울특별시  서울특별시    대한민국
# 32  KR  서울특별시  서울특별시    대한민국
# 33  KR  서울특별시  서울특별시    대한민국
# 34  KR  서울특별시  서울특별시    대한민국
# 35  KR  서울특별시  서울특별시    대한민국
# 36  KR    NaN    NaN    대한민국
# 37  KR  서울특별시  서울특별시    대한민국
# 38  KR  서울특별시  서울특별시    대한민국
# 39  KR  서울특별시  서울특별시    대한민국
# 40  KR    마포구  서울특별시    대한민국
# 41  KR  서울특별시  서울특별시    대한민국
# 42  KR  서울특별시  서울특별시    대한민국
# 43  KR  서울특별시  서울특별시    대한민국
# 44  KR  서울특별시  서울특별시    대한민국
# 45  KR  서울특별시  서울특별시    대한민국
# 46  KR  서울특별시  서울특별시    대한민국
# 47  KR    NaN    NaN    대한민국
# 48  KR  서울특별시  서울특별시    대한민국
# 49  KR  서울특별시  서울특별시    대한민국
#
#                                      formattedAddress crossStreet  \
# 0     [마포구 백범로 35 3층, 대흥동, 서울특별시, 서울특별시, 04107, 대한민국]         NaN
# 1                           [대흥동, 서울특별시, 서울특별시, 대한민국]         NaN
# 2   [서대문구 연세로4길 30, 신촌동, 서울특별시, 서울특별시, 120-833, 대한민국]         NaN
# 3   [서대문구 신촌역로 19-2 (신촌로터리), 신촌동, 서울특별시, 서울특별시, 12...       신촌로터리
# 4                           [대흥동, 서울특별시, 서울특별시, 대한민국]         NaN
# 5   [서대문구 이화여대1안길 9 2, 3층 (이대점), 신촌동, 서울특별시, 서울특별시...         이대점
# 6        [마포구 와우산로 157, 서교동, 마포구, 서울특별시, 04052, 대한민국]         NaN
# 7     [마포구 신수동 서강대학교 곤자가플라자, 대흥동, 서울특별시, 서울특별시, 대한민국]         NaN
# 8      [마포구 대흥로21길 4, 대흥동, 서울특별시, 서울특별시, 04106, 대한민국]         NaN
# 9        [서대문구 명물길 40 (신촌점), 신촌동, 서울특별시, 서울특별시, 대한민국]         신촌점
# 10                          [대흥동, 서울특별시, 서울특별시, 대한민국]         NaN
# 11                    [마포구 숭문길 108, 염리동, 서울특별시, 대한민국]         NaN
# 12  [서대문구 연세로4길 1 (신촌점), 신촌동, 서울특별시, 서울특별시, 120-83...         신촌점
# 13  [마포구 마포대로11길 44-19 (공덕직영점), 아현동, 서울특별시, 04132,...       공덕직영점
# 14             [서대문구 신촌로 89, 서교동, 서울특별시, 서울특별시, 대한민국]         NaN
# 15   [마포구 와우산로 147-1, 서교동, 서울특별시, 서울특별시, 04053, 대한민국]         NaN
# 16          [서대문구 명물길 10 5F, 신촌동, 서울특별시, 서울특별시, 대한민국]         NaN
# 17  [서대문구 신촌로 157-8 (이대1호점), 신촌동, 서울특별시, 서울특별시, 대한민국]       이대1호점
# 18  [마포구 와우산로27길 43 (홍대점), 서교동, 서울특별시, 서울특별시, 0405...         홍대점
# 19      [서대문구 신촌로 171 (이대점), 신촌동, 서울특별시, 서울특별시, 대한민국]         이대점
# 20  [르메이에르 5차빌딩 지하4층 (신촌로 109), 신촌동, 서대문구, 서울특별시, ...     신촌로 109
# 21  [서대문구 연세로4길 27 (신촌점), 신촌동, 서울특별시, 서울특별시, 120-8...         신촌점
# 22  [마포구 백범로 98-1 (대흥역점), 대흥동, 서울특별시, 서울특별시, 121-8...        대흥역점
# 23                 [신촌동, 서울특별시, 서울특별시, 120-833, 대한민국]         NaN
# 24        [서대문구 명물길26 (신촌점), 신촌동, 서울특별시, 서울특별시, 대한민국]         신촌점
# 25                                        [신촌동, 대한민국]         NaN
# 26                                        [신촌동, 대한민국]         NaN
# 27                    [서대문구, 신촌동, 서울특별시, 서울특별시, 대한민국]         NaN
# 28        [서대문구 연세로7안길 10-4, 신촌동, 서울특별시, 서울특별시, 대한민국]         NaN
# 29    [서대문구 이화여대2가길 12 (이대점), 신촌동, 서대문구, 서울특별시, 대한민국]         이대점
# 30  [서대문구 이화여대8길 2 (본점), 신촌동, 서울특별시, 서울특별시, 03767,...          본점
# 31  [서대문구 이화여대1길 46, 신촌동, 서울특별시, 서울특별시, 120-809, 대...         NaN
# 32   [서울시 서대문구 창천동, 신촌동, 서울특별시, 서울특별시, 120-834, 대한민국]         NaN
# 33  [서대문구 연세로 50-1 (신촌세브란스점), 신촌동, 서대문구, 서울특별시, 03...     신촌세브란스점
# 34                     [신촌점, 신촌동, 서울특별시, 서울특별시, 대한민국]         신촌점
# 35     [마포구 홍익로 10, 서교동, 서울특별시, 서울특별시, 121-837, 대한민국]         NaN
# 36                                        [신촌동, 대한민국]         NaN
# 37  [서대문구 명물길 70 2F (신촌), 신촌동, 서울특별시, 서울특별시, 120-8...          신촌
# 38  [서대문구 이화여대길 48 (이대점), 신촌동, 서대문구, 서울특별시, 03764,...         이대점
# 39                 [신촌동, 서울특별시, 서울특별시, 120-808, 대한민국]         NaN
# 40     [23 (Hongik-ro), 서교동, 마포구, 서울특별시, 04039, 대한민국]   Hongik-ro
# 41  [마포구 양화로21길 23, 서교동, 서울특별시, 서울특별시, 121-816, 대한민국]         NaN
# 42                          [서교동, 서울특별시, 서울특별시, 대한민국]         NaN
# 43  [서대문구 성산로22길 4, 연희동, 서울특별시, 서울특별시, 120-835, 대한민국]         NaN
# 44  [마포구 와우산로23길 14, 서교동, 서울특별시, 서울특별시, 121-837, 대...         NaN
# 45  [서대문구 신촌로 25 (홍대점), 신촌동, 서울특별시, 서울특별시, 120-836...         홍대점
# 46               [마포구 연희로 7, 신촌동, 서울특별시, 서울특별시, 대한민국]         NaN
# 47                                        [서교동, 대한민국]         NaN
# 48    [마포구 와우산로29다길 10, 서교동, 마포구, 서울특별시, 04053, 대한민국]         NaN
# 49  [서대문구 이화여대길 52 국제교육관 1층 (이화여대점), 신촌동, 서울특별시, 서...       이화여대점
#
#    neighborhood                        id
# 0           NaN  4e5efed218a870f60f3440f1
# 1           NaN  4da5639d0cb6d75e29f6b81d
# 2           NaN  4e9154780aafb4070c48d930
# 3           NaN  4b982966f964a5209a3035e3
# 4           NaN  4d6da6f630d5b1f73449bc42
# 5           NaN  50753c8de4b0c8feb2112189
# 6           NaN  4b9a3498f964a5206fa435e3
# 7           NaN  4ca55304d971b1f7f504f6e0
# 8           NaN  4c7e0a5fb53db1f757e29e11
# 9           창천동  50113732e4b0c3490cf8c245
# 10          NaN  4fe0575ee4b02857f0b7a694
# 11          NaN  51bc3b3f498e1757e856245d
# 12          NaN  4bf1fea178cec9289617bb86
# 13          공덕동  5b7cddcfdab4b1002b13d36d
# 14          NaN  4e0fee9b62e1d997a692f3e5
# 15          NaN  5211a40f11d24231a48cde3c
# 16          NaN  57021bd9498eb04614873004
# 17          NaN  4e197dcf14957dc705e18647
# 18          NaN  5811c1de38faec4196b60196
# 19          NaN  4e3d3d2eb61cb577be740724
# 20          NaN  57ebba79498ec263bf01cb35
# 21          NaN  51ceb047498ec2e45b4332d8
# 22          NaN  4b8a3152f964a5208c6332e3
# 23          NaN  4e01bfe3d22db37fb02900d1
# 24          NaN  4fc1a252e4b099ce1739d50a
# 25          NaN  55a78902498ee1734ee7acf4
# 26          NaN  56c3c739cd101cd7cb1300c9
# 27          NaN  4cce7c44c9b84688cce3c8c3
# 28          NaN  4bd67311637ba5930f4bf870
# 29          NaN  4cc2b3a53d7fa1cd2b8ea05f
# 30          NaN  4d9ae4659298b1f77d744a38
# 31          NaN  4d9aeb063f785481e3abd3d1
# 32          NaN  4cd65484886cb60c0f888989
# 33          NaN  51d5117e498ec882707a4b4d
# 34          NaN  4db287b54b220b5fbb043b70
# 35          NaN  4b6e7161f964a520a4bd2ce3
# 36          NaN  5041e031e4b07118808dfdb1
# 37          NaN  500f97d8e4b0b1bc5e3caceb
# 38          NaN  4c565646cc96c9b638a1762e
# 39          NaN  4bc99af6937ca593d704a692
# 40  Seogyo-dong  5de25f04a191b90008eb9c4a
# 41          NaN  54f1594e498ef9bd207b8478
# 42          NaN  4e81473bdab498c614e96e6a
# 43          NaN  4d6f2c083599370459080a9d
# 44          NaN  50c1d4c0e4b07236438c8ace
# 45          NaN  50001310e4b0e08eeeb2fbfa
# 46          NaN  52902cbe11d22f9fcc401aa4
# 47          NaN  50220736e4b05f49ad9abe09
# 48          서교동  59554384b9a5a80f8303d367
# 49          NaN  4d75e3578d7e236a81cbaf28

# %% [markdown]
# So the cafes around Sogang University is..

# %%
for lat, lng, name in zip(sogang_filtered.lat, sogang_filtered.lng, sogang_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=name,
        fill = False,
    ).add_to(map_Sogang)

map_Sogang
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Now, it's time to search the cafes around Korea university

# %%
from geopy.geocoders import Nominatim
def lat_lng(address):
    geolocator = Nominatim(user_agent = 'To_explorer')
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return [latitude, longitude]

Koruniv_latlng = lat_lng('145 Anam-ro, Anam-dong, Seongbuk-gu, Seoul')
print("Latitude, Longitude data is created!\n")
# Out:
# Latitude, Longitude data is created!

# %%
Koruniv_x, Koruniv_y = lat_lng_to_xy(Koruniv_latlng[0], Koruniv_latlng[1])
print('Korea university UTM is ({}, {})'.format(Koruniv_x, Koruniv_y))
# Out:
# Korea university UTM is (325723.58842634264, 4161782.3818812408)

# %%
map_Koruniv = folium.Map(location=Koruniv_latlng, zoom_start=13)
folium.Marker(location=Koruniv_latlng, popup='Center').add_to(map_Koruniv)
folium.Circle(Koruniv_latlng, radius=1500, color='blue', fill=False).add_to(map_Koruniv)
map_Koruniv
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Get information of cafes around the area as above

# %%
koruniv_address = '145 Anam-ro, Anam-dong, Seongbuk-gu, Seoul'
geolocator = Nominatim(user_agent = 'foursquare_agent')
location = geolocator.geocode(koruniv_address)
latitude = location.latitude
longitude = location.longitude
search_query = 'Cafe'
radius = 1500
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e6a0c74211536001b3dfdd7'},
#  'response': {'venues': [{'id': '4d0c8964bdbfa35d6e1e6472',
#     'name': "Cafe L'abri",
#     'location': {'address': '성북구 개운사1길 29',
#      'lat': 37.58740584259717,
#      'lng': 127.02896155780898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58740584259717,
#        'lng': 127.02896155780898}],
#      'distance': 263,
#      'postalCode': '136-075',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 개운사1길 29',
#       '안암동',
#       '서울특별시',
#       '서울특별시',
#       '136-075',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4bf90093b182c9b69651785a',
#     'name': 'cafe b',
#     'location': {'address': '성북구 보문로30길 71',
#      'lat': 37.590640291014736,
#      'lng': 127.01978167791066,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.590640291014736,
#        'lng': 127.01978167791066}],
#      'distance': 718,
#      'postalCode': '136-052',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 보문로30길 71',
#       '동선동',
#       '서울특별시',
#       '서울특별시',
#       '136-052',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4d88875c4757721e7bc78e69',
#     'name': 'Café Secret',
#     'location': {'address': '성북구 인촌로24길 39',
#      'lat': 37.58469060525004,
#      'lng': 127.02953184708089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58469060525004,
#        'lng': 127.02953184708089}],
#      'distance': 367,
#      'postalCode': '136-075',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 인촌로24길 39',
#       '안암동',
#       '서울특별시',
#       '서울특별시',
#       '136-075',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4eccd86902d557995136f91f',
#     'name': 'cafe PUBLIC',
#     'location': {'address': '서울특별시 성북구 안암동',
#      'lat': 37.58595598744507,
#      'lng': 127.03059076848443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58595598744507,
#        'lng': 127.03059076848443}],
#      'distance': 399,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['서울특별시 성북구 안암동', '안암동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4df08045227193bb466b7d45',
#     'name': 'Cafe Smile :D',
#     'location': {'lat': 37.585350090078116,
#      'lng': 127.03042301958645,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.585350090078116,
#        'lng': 127.03042301958645}],
#      'distance': 402,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '51728f29e4b021698a482d88',
#     'name': 'Cafe 라센느',
#     'location': {'lat': 37.582589122785144,
#      'lng': 127.02242304507118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.582589122785144,
#        'lng': 127.02242304507118}],
#      'distance': 555,
#      'cc': 'KR',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4de9eeb51f6e3ddebdbe878f',
#     'name': 'Cafe de GOUTIER',
#     'location': {'address': '안암동5가 안암로터리',
#      'lat': 37.58260318701594,
#      'lng': 127.0294636981459,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58260318701594,
#        'lng': 127.0294636981459}],
#      'distance': 534,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['안암동5가 안암로터리', '용신동', '성북구', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4db54a1cfa8c350240f5d469',
#     'name': 'cafe Florence',
#     'location': {'address': '성북구 동선동3가 234-102',
#      'lat': 37.59154272246439,
#      'lng': 127.02053039299712,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.59154272246439,
#        'lng': 127.02053039299712}],
#      'distance': 738,
#      'postalCode': '136-053',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 동선동3가 234-102',
#       '동선동',
#       '서울특별시',
#       '서울특별시',
#       '136-053',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c96d1ff82b56dcb3012e5aa',
#     'name': 'Cafe Centennial',
#     'location': {'address': '성북구 안암동 고려대학교 백주년기념관 1층',
#      'lat': 37.5892864790531,
#      'lng': 127.03434625932718,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5892864790531,
#        'lng': 127.03434625932718}],
#      'distance': 782,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 안암동 고려대학교 백주년기념관 1층',
#       '안암동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c7dca54d654370436a4c1a2',
#     'name': 'Cafe 7gram',
#     'location': {'crossStreet': '고려대점',
#      'lat': 37.58703336,
#      'lng': 127.03520621,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58703336,
#        'lng': 127.03520621}],
#      'distance': 800,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['제기동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '5160c555e4b0db8cdc7a5be6',
#     'name': 'CNN Café',
#     'location': {'address': '성북구 안암로 145 고려대학교 백주년기념관 1층',
#      'crossStreet': '고대점',
#      'lat': 37.58925757933431,
#      'lng': 127.03434762290917,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58925757933431,
#        'lng': 127.03434762290917}],
#      'distance': 781,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 안암로 145 고려대학교 백주년기념관 1층 (고대점)',
#       '안암동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c4fd9307537e21ecfabed88',
#     'name': 'Book Cafe 소일',
#     'location': {'address': '성북구 보문로32길 40',
#      'lat': 37.590181789507064,
#      'lng': 127.01840030573004,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.590181789507064,
#        'lng': 127.01840030573004}],
#      'distance': 790,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 보문로32길 40', '동선동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4bf1303524f020a1aac8684f',
#     'name': 'Cafe Mug (카페머그)',
#     'location': {'address': '성북구 동소문로22길 29-1',
#      'lat': 37.59294262853395,
#      'lng': 127.01777398838553,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.59294262853395,
#        'lng': 127.01777398838553}],
#      'distance': 1020,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 동소문로22길 29-1',
#       '동선동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c80764c51ada1cdee560a10',
#     'name': 'cafe 7gram',
#     'location': {'crossStreet': '성신여대',
#      'lat': 37.592688865966586,
#      'lng': 127.01689174913747,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.592688865966586,
#        'lng': 127.01689174913747}],
#      'distance': 1059,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['동선동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4f75ad1fe4b09b101302e88a',
#     'name': 'soso cafe (소소한)',
#     'location': {'lat': 37.58903176921664,
#      'lng': 127.03540290028823,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58903176921664,
#        'lng': 127.03540290028823}],
#      'distance': 859,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['종암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4f5ec7f2e4b04ddc38f7a07c',
#     'name': 'Café NESCAFÉ',
#     'location': {'address': '성북구 동소문로 21-22 5 2층, 3층',
#      'crossStreet': '성신여대점',
#      'lat': 37.59285554683292,
#      'lng': 127.01737351588437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.59285554683292,
#        'lng': 127.01737351588437}],
#      'distance': 1039,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 동소문로 21-22 5 2층, 3층 (성신여대점)',
#       '동선동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '50c70e48e4b0b612ce994ab0',
#     'name': '101 cafe',
#     'location': {'lat': 37.59309542625074,
#      'lng': 127.01933500844157,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.59309542625074,
#        'lng': 127.01933500844157}],
#      'distance': 938,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['동선동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4e92fd1302d5dcbe604e2dc8',
#     'name': 'Café NESCAFÉ',
#     'location': {'address': '외대 국제학사 1층',
#      'lat': 37.575932,
#      'lng': 127.024121,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.575932,
#        'lng': 127.024121}],
#      'distance': 1202,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['외대 국제학사 1층', '용신동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '54fc036f498edf0d9bea98ee',
#     'name': "카페데코믹스 (CAFE de' COMICS)",
#     'location': {'address': '성북구 동소문로20다길 7',
#      'crossStreet': '성신여대점',
#      'lat': 37.59174539403649,
#      'lng': 127.01723388970095,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.59174539403649,
#        'lng': 127.01723388970095}],
#      'distance': 971,
#      'cc': 'KR',
#      'neighborhood': '동선동',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 동소문로20다길 7 (성신여대점)', '동선동', '대한민국']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b18',
#       'name': 'Comic Shop',
#       'pluralName': 'Comic Shops',
#       'shortName': 'Comic Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4e5f5409ae60c16e993ff806',
#     'name': '카페94th (CAFE 94th)',
#     'location': {'address': '성북구 동소문로 94',
#      'lat': 37.59272224128639,
#      'lng': 127.01538171098424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.59272224128639,
#        'lng': 127.01538171098424}],
#      'distance': 1167,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 동소문로 94', '동선동', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4fbf3394e4b0ed139841fc4d',
#     'name': 'Cafe 1_ROHA (카페 일로하)',
#     'location': {'address': '동대문구 정릉천동로 58',
#      'crossStreet': '롯데캐슬 피렌체 1층',
#      'lat': 37.57741052964353,
#      'lng': 127.03675003047763,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.57741052964353,
#        'lng': 127.03675003047763}],
#      'distance': 1387,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['동대문구 정릉천동로 58 (롯데캐슬 피렌체 1층)',
#       '용신동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4df5f7266284fefe8fca58db',
#     'name': 'cafe Ti-amo (종로 숭인점)',
#     'location': {'lat': 37.57423815722068,
#      'lng': 127.02007426173235,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.57423815722068,
#        'lng': 127.02007426173235}],
#      'distance': 1478,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['숭인2동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c7f8015fb74236a6829fab9',
#     'name': 'Cafe Ti-Amo',
#     'location': {'address': '성북구 동소문로2길 43',
#      'crossStreet': '삼선교점',
#      'lat': 37.588192,
#      'lng': 127.008717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.588192,
#        'lng': 127.008717}],
#      'distance': 1547,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 동소문로2길 43 (삼선교점)',
#       '삼선동',
#       '서울특별시',
#       '서울특별시',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4ce48d70e860a14334c28da1',
#     'name': 'Pork cutlet & Cafe (일루)',
#     'location': {'address': '동대문구 신설동 104-8 진흥빌딩 별관 1 층',
#      'lat': 37.57395145583748,
#      'lng': 127.02428251504898,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.57395145583748,
#        'lng': 127.02428251504898}],
#      'distance': 1419,
#      'postalCode': '130-812',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['동대문구 신설동 104-8 진흥빌딩 별관 1 층',
#       '용신동',
#       '서울특별시',
#       '서울특별시',
#       '130-812',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '59a014ddd4cc987933371a9a',
#     'name': 'Cafe IL Luogo (카페일루오고)',
#     'location': {'address': '인촌로16길 4',
#      'lat': 37.586394,
#      'lng': 127.024461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.586394,
#        'lng': 127.024461}],
#      'distance': 150,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['인촌로16길 4', '안암동', '성북구', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4d9eef90640b54812a9fd42d',
#     'name': 'Cafe gA',
#     'location': {'address': '동대문구 왕산로 192',
#      'lat': 37.579886510287295,
#      'lng': 127.04441299670134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.579886510287295,
#        'lng': 127.04441299670134}],
#      'distance': 1777,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['동대문구 왕산로 192', '전농1동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c874b9956e037041425b1a3',
#     'name': 'cafe Port',
#     'location': {'address': '성북구 인촌로26길 45-9',
#      'lat': 37.584589,
#      'lng': 127.030369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.584589,
#        'lng': 127.030369}],
#      'distance': 435,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 인촌로26길 45-9', '안암동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4cc6822d1e596dcb31e6de67',
#     'name': 'cafe 더 힐링',
#     'location': {'lat': 37.587234,
#      'lng': 127.029296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.587234,
#        'lng': 127.029296}],
#      'distance': 286,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4d900811788c54812db65cfd',
#     'name': 'Cafe The Healing',
#     'location': {'lat': 37.587345,
#      'lng': 127.029291,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.587345,
#        'lng': 127.029291}],
#      'distance': 289,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c4ac83f42b4d13aeef3b77d',
#     'name': 'Cafe b1',
#     'location': {'address': '성북구 인촌로27길 25',
#      'lat': 37.58745853070703,
#      'lng': 127.0297630134713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58745853070703,
#        'lng': 127.0297630134713}],
#      'distance': 332,
#      'postalCode': '136-075',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 인촌로27길 25',
#       '안암동',
#       '서울특별시',
#       '서울특별시',
#       '136-075',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '5c8638936fd626002ce7fcbb',
#     'name': 'Cafe J',
#     'location': {'lat': 37.587975,
#      'lng': 127.02938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.587975,
#        'lng': 127.02938}],
#      'distance': 322,
#      'postalCode': '136-075',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '서울특별시', '서울특별시', '136-075', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '53e5a4bb498ec3e13b542331',
#     'name': 'Cafe Good News',
#     'location': {'address': '성북구 개운사길 32',
#      'lat': 37.58779357553443,
#      'lng': 127.02938139438629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58779357553443,
#        'lng': 127.02938139438629}],
#      'distance': 314,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 개운사길 32', '안암동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4eef2bf06da153687c96dbe2',
#     'name': 'café FLOWER',
#     'location': {'address': '성북구 보문로34다길 2',
#      'lat': 37.58922905879807,
#      'lng': 127.02029446338936,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58922905879807,
#        'lng': 127.02029446338936}],
#      'distance': 592,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 보문로34다길 2', '안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '51d4e782e4b098c3c4921bc2',
#     'name': 'Cafe C Coffee',
#     'location': {'crossStreet': '고려대학교 후문 앞',
#      'lat': 37.58671689248664,
#      'lng': 127.03015042680232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58671689248664,
#        'lng': 127.03015042680232}],
#      'distance': 353,
#      'cc': 'KR',
#      'city': 'Anam-dong',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['고려대학교 후문 앞', '안암동', '안암동', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '54bb6cd7498ec690651d9134',
#     'name': 'cafe de nata',
#     'location': {'address': '성북구 인촌로28길 11',
#      'lat': 37.5860285955663,
#      'lng': 127.03054358914598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5860285955663,
#        'lng': 127.03054358914598}],
#      'distance': 393,
#      'postalCode': '136-075',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 인촌로28길 11',
#       '안암동',
#       '서울특별시',
#       '서울특별시',
#       '136-075',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c7f792ba7958cfac8b6902b',
#     'name': 'Cafe 103',
#     'location': {'address': '성북구 인촌로26길 45-5',
#      'lat': 37.5845616548687,
#      'lng': 127.03034438715737,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5845616548687,
#        'lng': 127.03034438715737}],
#      'distance': 435,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['성북구 인촌로26길 45-5', '안암동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4d296375b818a35dd6a89e8a',
#     'name': 'cafe;b2win',
#     'location': {'lat': 37.5887754835493,
#      'lng': 127.02246622608558,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.5887754835493,
#        'lng': 127.02246622608558}],
#      'distance': 403,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '597d928035dfa72979489b48',
#     'name': 'Cafe Kuwall',
#     'location': {'lat': 37.589474,
#      'lng': 127.01955,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.589474,
#        'lng': 127.01955}],
#      'distance': 662,
#      'cc': 'KR',
#      'neighborhood': '동선동',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['동선동', '성북구', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '5a2de00bda5ede1661ccad83',
#     'name': '본죽&비빔밥Cafe',
#     'location': {'address': '146-18',
#      'crossStreet': '안암동5가',
#      'lat': 37.586135,
#      'lng': 127.029222,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.586135,
#        'lng': 127.029222}],
#      'distance': 276,
#      'postalCode': '02855',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['146-18 (안암동5가)',
#       '안암동',
#       '성북구',
#       '서울특별시',
#       '02855',
#       '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '58bfc94137318118df1d8463',
#     'name': 'Doctor Internet Game Cafe',
#     'location': {'lat': 37.586146,
#      'lng': 127.029029,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.586146,
#        'lng': 127.029029}],
#      'distance': 259,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d18d941735',
#       'name': 'Gaming Cafe',
#       'pluralName': 'Gaming Cafes',
#       'shortName': 'Gaming Cafe',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gamingcafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4de335511f6e3190cd230519',
#     'name': 'Cafe Daniel',
#     'location': {'address': '동대문구 제기동142-2',
#      'lat': 37.58627026152853,
#      'lng': 127.03251877369333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58627026152853,
#        'lng': 127.03251877369333}],
#      'distance': 563,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['동대문구 제기동142-2', '안암동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '596424eaa2c00b527a8f18da',
#     'name': 'Cafe Endlong',
#     'location': {'lat': 37.575012,
#      'lng': 127.0266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.575012,
#        'lng': 127.0266}],
#      'distance': 1292,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['용신동', '동대문구', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '59b7a96e898bdc4e5fccdc45',
#     'name': 'Cafe De Brussels',
#     'location': {'crossStreet': '안암로9가길 71',
#      'lat': 37.582334,
#      'lng': 127.028259,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.582334,
#        'lng': 127.028259}],
#      'distance': 511,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['안암로9가길 71', '안암동', '성북구', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '52e351c211d253c59c85a570',
#     'name': 'Lime PC & Cafe',
#     'location': {'lat': 37.586177,
#      'lng': 127.029142,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.586177,
#        'lng': 127.029142}],
#      'distance': 268,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1f0941735',
#       'name': 'Internet Cafe',
#       'pluralName': 'Internet Cafes',
#       'shortName': 'Internet Cafe',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/internetcafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '5a082dbf6bd36b49e5b39ffe',
#     'name': 'Cafe Amor Fati',
#     'location': {'lat': 37.589473,
#      'lng': 127.016161,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.589473,
#        'lng': 127.016161}],
#      'distance': 936,
#      'postalCode': '02848',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['삼선동', '성북구', '서울특별시', '02848', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '512ca042e4b0e4a8799178d4',
#     'name': 'Cafe Cantata',
#     'location': {'address': '안암오거리',
#      'lat': 37.583034438909976,
#      'lng': 127.02953184708089,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.583034438909976,
#        'lng': 127.02953184708089}],
#      'distance': 498,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암오거리', '안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4e898860550364195b9c07a5',
#     'name': 'Cafe De Coutier',
#     'location': {'lat': 37.58254,
#      'lng': 127.029417,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58254,
#        'lng': 127.029417}],
#      'distance': 537,
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['용신동', '서울특별시', '서울특별시', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4c01e53027dcc928505ae152',
#     'name': 'cafe la magia',
#     'location': {'lat': 37.586491,
#      'lng': 127.031838,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.586491,
#        'lng': 127.031838}],
#      'distance': 502,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '4cc8ba61e7926dcbeaf55777',
#     'name': '바른생할cafe',
#     'location': {'lat': 37.58694317239891,
#      'lng': 127.03009800499598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.58694317239891,
#        'lng': 127.03009800499598}],
#      'distance': 350,
#      'cc': 'KR',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False},
#    {'id': '5a5b1be9336273355f568774',
#     'name': 'Medit Cafe',
#     'location': {'lat': 37.585279,
#      'lng': 127.029072,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 37.585279,
#        'lng': 127.029072}],
#      'distance': 298,
#      'postalCode': '02855',
#      'cc': 'KR',
#      'city': '서울특별시',
#      'state': '서울특별시',
#      'country': '대한민국',
#      'formattedAddress': ['안암동', '성북구', '서울특별시', '02855', '대한민국']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1584008511',
#     'hasPerk': False}]}}

# %%
venues = results['response']['venues']
koruniv = json_normalize(venues)
koruniv.head()
# Out:
# <ipython-input-221-269c83b5866e>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   koruniv = json_normalize(venues)
#                          id           name  \
# 0  4d0c8964bdbfa35d6e1e6472    Cafe L'abri
# 1  4bf90093b182c9b69651785a         cafe b
# 2  4d88875c4757721e7bc78e69    Café Secret
# 3  4eccd86902d557995136f91f    cafe PUBLIC
# 4  4df08045227193bb466b7d45  Cafe Smile :D
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1584008511    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1584008511    False
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1584008511    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1584008511    False
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1584008511    False
#
#   location.address  location.lat  location.lng  \
# 0     성북구 개운사1길 29     37.587406    127.028962
# 1    성북구 보문로30길 71     37.590640    127.019782
# 2    성북구 인촌로24길 39     37.584691    127.029532
# 3    서울특별시 성북구 안암동     37.585956    127.030591
# 4              NaN     37.585350    127.030423
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 37.58740584259717...                263
# 1  [{'label': 'display', 'lat': 37.59064029101473...                718
# 2  [{'label': 'display', 'lat': 37.58469060525004...                367
# 3  [{'label': 'display', 'lat': 37.58595598744507...                399
# 4  [{'label': 'display', 'lat': 37.58535009007811...                402
#
#   location.postalCode location.cc location.city location.state  \
# 0             136-075          KR         서울특별시          서울특별시
# 1             136-052          KR         서울특별시          서울특별시
# 2             136-075          KR         서울특별시          서울특별시
# 3                 NaN          KR         서울특별시          서울특별시
# 4                 NaN          KR         서울특별시          서울특별시
#
#   location.country                          location.formattedAddress  \
# 0             대한민국   [성북구 개운사1길 29, 안암동, 서울특별시, 서울특별시, 136-075, 대한민국]
# 1             대한민국  [성북구 보문로30길 71, 동선동, 서울특별시, 서울특별시, 136-052, 대한민국]
# 2             대한민국  [성북구 인촌로24길 39, 안암동, 서울특별시, 서울특별시, 136-075, 대한민국]
# 3             대한민국           [서울특별시 성북구 안암동, 안암동, 서울특별시, 서울특별시, 대한민국]
# 4             대한민국                          [안암동, 서울특별시, 서울특별시, 대한민국]
#
#   location.crossStreet location.neighborhood
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN

# %%
#Drop any colums without its name starting with 'location'
koruniv_columns = ['name', 'categories'] + [col for col in koruniv.columns if col.startswith('location.')] + ['id']
koruniv_filtered = koruniv.loc[:, filtered_columns]

koruniv_filtered['categories'] = koruniv_filtered.apply(get_category_type, axis=1)

#Clean column names with only last term
koruniv_filtered.columns = [column.split('.')[-1] for column in koruniv_filtered.columns]
koruniv_filtered
# Out:
#                          name         categories                      address  \
# 0                 Cafe L'abri        Coffee Shop                 성북구 개운사1길 29
# 1                      cafe b               Café                성북구 보문로30길 71
# 2                 Café Secret               Café                성북구 인촌로24길 39
# 3                 cafe PUBLIC               Café                서울특별시 성북구 안암동
# 4               Cafe Smile :D               Café                          NaN
# 5                    Cafe 라센느               Café                          NaN
# 6             Cafe de GOUTIER               Café                  안암동5가 안암로터리
# 7               cafe Florence               Café            성북구 동선동3가 234-102
# 8             Cafe Centennial               Café      성북구 안암동 고려대학교 백주년기념관 1층
# 9                  Cafe 7gram               Café                          NaN
# 10                   CNN Café        Coffee Shop  성북구 안암로 145 고려대학교 백주년기념관 1층
# 11               Book Cafe 소일               Café                성북구 보문로32길 40
# 12            Cafe Mug (카페머그)        Coffee Shop             성북구 동소문로22길 29-1
# 13                 cafe 7gram        Coffee Shop                          NaN
# 14            soso cafe (소소한)               Café                          NaN
# 15               Café NESCAFÉ               Café      성북구 동소문로 21-22 5 2층, 3층
# 16                   101 cafe               Café                          NaN
# 17               Café NESCAFÉ               Café                   외대 국제학사 1층
# 18   카페데코믹스 (CAFE de' COMICS)         Comic Shop               성북구 동소문로20다길 7
# 19         카페94th (CAFE 94th)               Café                  성북구 동소문로 94
# 20       Cafe 1_ROHA (카페 일로하)               Café                동대문구 정릉천동로 58
# 21       cafe Ti-amo (종로 숭인점)               None                          NaN
# 22                Cafe Ti-Amo        Coffee Shop                성북구 동소문로2길 43
# 23    Pork cutlet & Cafe (일루)         Restaurant   동대문구 신설동 104-8 진흥빌딩 별관 1 층
# 24     Cafe IL Luogo (카페일루오고)               Café                     인촌로16길 4
# 25                    Cafe gA               Café                 동대문구 왕산로 192
# 26                  cafe Port               Café              성북구 인촌로26길 45-9
# 27                  cafe 더 힐링               Café                          NaN
# 28           Cafe The Healing               Café                          NaN
# 29                    Cafe b1               Café                성북구 인촌로27길 25
# 30                     Cafe J               Café                          NaN
# 31             Cafe Good News               Café                  성북구 개운사길 32
# 32                café FLOWER               Café                성북구 보문로34다길 2
# 33              Cafe C Coffee        Coffee Shop                          NaN
# 34               cafe de nata       Dessert Shop                성북구 인촌로28길 11
# 35                   Cafe 103               Café              성북구 인촌로26길 45-5
# 36                 cafe;b2win               Café                          NaN
# 37                Cafe Kuwall               Café                          NaN
# 38                 본죽&비빔밥Cafe  Korean Restaurant                       146-18
# 39  Doctor Internet Game Cafe        Gaming Cafe                          NaN
# 40                Cafe Daniel               Café                동대문구 제기동142-2
# 41               Cafe Endlong               Café                          NaN
# 42           Cafe De Brussels               Café                          NaN
# 43             Lime PC & Cafe      Internet Cafe                          NaN
# 44             Cafe Amor Fati               Café                          NaN
# 45               Cafe Cantata               Café                        안암오거리
# 46            Cafe De Coutier               Café                          NaN
# 47              cafe la magia        Pizza Place                          NaN
# 48                   바른생할cafe        Coffee Shop                          NaN
# 49                 Medit Cafe        Coffee Shop                          NaN
#
#           lat         lng                                     labeledLatLngs  \
# 0   37.587406  127.028962  [{'label': 'display', 'lat': 37.58740584259717...
# 1   37.590640  127.019782  [{'label': 'display', 'lat': 37.59064029101473...
# 2   37.584691  127.029532  [{'label': 'display', 'lat': 37.58469060525004...
# 3   37.585956  127.030591  [{'label': 'display', 'lat': 37.58595598744507...
# 4   37.585350  127.030423  [{'label': 'display', 'lat': 37.58535009007811...
# 5   37.582589  127.022423  [{'label': 'display', 'lat': 37.58258912278514...
# 6   37.582603  127.029464  [{'label': 'display', 'lat': 37.58260318701594...
# 7   37.591543  127.020530  [{'label': 'display', 'lat': 37.59154272246439...
# 8   37.589286  127.034346  [{'label': 'display', 'lat': 37.5892864790531,...
# 9   37.587033  127.035206  [{'label': 'display', 'lat': 37.58703336, 'lng...
# 10  37.589258  127.034348  [{'label': 'display', 'lat': 37.58925757933431...
# 11  37.590182  127.018400  [{'label': 'display', 'lat': 37.59018178950706...
# 12  37.592943  127.017774  [{'label': 'display', 'lat': 37.59294262853395...
# 13  37.592689  127.016892  [{'label': 'display', 'lat': 37.59268886596658...
# 14  37.589032  127.035403  [{'label': 'display', 'lat': 37.58903176921664...
# 15  37.592856  127.017374  [{'label': 'display', 'lat': 37.59285554683292...
# 16  37.593095  127.019335  [{'label': 'display', 'lat': 37.59309542625074...
# 17  37.575932  127.024121  [{'label': 'display', 'lat': 37.575932, 'lng':...
# 18  37.591745  127.017234  [{'label': 'display', 'lat': 37.59174539403649...
# 19  37.592722  127.015382  [{'label': 'display', 'lat': 37.59272224128639...
# 20  37.577411  127.036750  [{'label': 'display', 'lat': 37.57741052964353...
# 21  37.574238  127.020074  [{'label': 'display', 'lat': 37.57423815722068...
# 22  37.588192  127.008717  [{'label': 'display', 'lat': 37.588192, 'lng':...
# 23  37.573951  127.024283  [{'label': 'display', 'lat': 37.57395145583748...
# 24  37.586394  127.024461  [{'label': 'display', 'lat': 37.586394, 'lng':...
# 25  37.579887  127.044413  [{'label': 'display', 'lat': 37.57988651028729...
# 26  37.584589  127.030369  [{'label': 'display', 'lat': 37.584589, 'lng':...
# 27  37.587234  127.029296  [{'label': 'display', 'lat': 37.587234, 'lng':...
# 28  37.587345  127.029291  [{'label': 'display', 'lat': 37.587345, 'lng':...
# 29  37.587459  127.029763  [{'label': 'display', 'lat': 37.58745853070703...
# 30  37.587975  127.029380  [{'label': 'display', 'lat': 37.587975, 'lng':...
# 31  37.587794  127.029381  [{'label': 'display', 'lat': 37.58779357553443...
# 32  37.589229  127.020294  [{'label': 'display', 'lat': 37.58922905879807...
# 33  37.586717  127.030150  [{'label': 'display', 'lat': 37.58671689248664...
# 34  37.586029  127.030544  [{'label': 'display', 'lat': 37.5860285955663,...
# 35  37.584562  127.030344  [{'label': 'display', 'lat': 37.5845616548687,...
# 36  37.588775  127.022466  [{'label': 'display', 'lat': 37.5887754835493,...
# 37  37.589474  127.019550  [{'label': 'display', 'lat': 37.589474, 'lng':...
# 38  37.586135  127.029222  [{'label': 'display', 'lat': 37.586135, 'lng':...
# 39  37.586146  127.029029  [{'label': 'display', 'lat': 37.586146, 'lng':...
# 40  37.586270  127.032519  [{'label': 'display', 'lat': 37.58627026152853...
# 41  37.575012  127.026600  [{'label': 'display', 'lat': 37.575012, 'lng':...
# 42  37.582334  127.028259  [{'label': 'display', 'lat': 37.582334, 'lng':...
# 43  37.586177  127.029142  [{'label': 'display', 'lat': 37.586177, 'lng':...
# 44  37.589473  127.016161  [{'label': 'display', 'lat': 37.589473, 'lng':...
# 45  37.583034  127.029532  [{'label': 'display', 'lat': 37.58303443890997...
# 46  37.582540  127.029417  [{'label': 'display', 'lat': 37.58254, 'lng': ...
# 47  37.586491  127.031838  [{'label': 'display', 'lat': 37.586491, 'lng':...
# 48  37.586943  127.030098  [{'label': 'display', 'lat': 37.58694317239891...
# 49  37.585279  127.029072  [{'label': 'display', 'lat': 37.585279, 'lng':...
#
#     distance postalCode  cc       city  state country  \
# 0        263    136-075  KR      서울특별시  서울특별시    대한민국
# 1        718    136-052  KR      서울특별시  서울특별시    대한민국
# 2        367    136-075  KR      서울특별시  서울특별시    대한민국
# 3        399        NaN  KR      서울특별시  서울특별시    대한민국
# 4        402        NaN  KR      서울특별시  서울특별시    대한민국
# 5        555        NaN  KR        NaN  서울특별시    대한민국
# 6        534        NaN  KR      서울특별시  서울특별시    대한민국
# 7        738    136-053  KR      서울특별시  서울특별시    대한민국
# 8        782        NaN  KR      서울특별시  서울특별시    대한민국
# 9        800        NaN  KR        NaN    NaN    대한민국
# 10       781        NaN  KR      서울특별시  서울특별시    대한민국
# 11       790        NaN  KR      서울특별시  서울특별시    대한민국
# 12      1020        NaN  KR      서울특별시  서울특별시    대한민국
# 13      1059        NaN  KR        NaN    NaN    대한민국
# 14       859        NaN  KR        NaN    NaN    대한민국
# 15      1039        NaN  KR      서울특별시  서울특별시    대한민국
# 16       938        NaN  KR        NaN    NaN    대한민국
# 17      1202        NaN  KR        NaN    NaN    대한민국
# 18       971        NaN  KR        NaN    NaN    대한민국
# 19      1167        NaN  KR      서울특별시    NaN    대한민국
# 20      1387        NaN  KR      서울특별시  서울특별시    대한민국
# 21      1478        NaN  KR      서울특별시  서울특별시    대한민국
# 22      1547        NaN  KR      서울특별시  서울특별시    대한민국
# 23      1419    130-812  KR      서울특별시  서울특별시    대한민국
# 24       150        NaN  KR      서울특별시  서울특별시    대한민국
# 25      1777        NaN  KR      서울특별시  서울특별시    대한민국
# 26       435        NaN  KR      서울특별시  서울특별시    대한민국
# 27       286        NaN  KR        NaN    NaN    대한민국
# 28       289        NaN  KR        NaN    NaN    대한민국
# 29       332    136-075  KR      서울특별시  서울특별시    대한민국
# 30       322    136-075  KR      서울특별시  서울특별시    대한민국
# 31       314        NaN  KR      서울특별시  서울특별시    대한민국
# 32       592        NaN  KR        NaN    NaN    대한민국
# 33       353        NaN  KR  Anam-dong  서울특별시    대한민국
# 34       393    136-075  KR      서울특별시  서울특별시    대한민국
# 35       435        NaN  KR      서울특별시  서울특별시    대한민국
# 36       403        NaN  KR        NaN    NaN    대한민국
# 37       662        NaN  KR      서울특별시  서울특별시    대한민국
# 38       276      02855  KR      서울특별시  서울특별시    대한민국
# 39       259        NaN  KR        NaN    NaN    대한민국
# 40       563        NaN  KR      서울특별시  서울특별시    대한민국
# 41      1292        NaN  KR      서울특별시  서울특별시    대한민국
# 42       511        NaN  KR      서울특별시  서울특별시    대한민국
# 43       268        NaN  KR        NaN    NaN    대한민국
# 44       936      02848  KR      서울특별시  서울특별시    대한민국
# 45       498        NaN  KR        NaN    NaN    대한민국
# 46       537        NaN  KR      서울특별시  서울특별시    대한민국
# 47       502        NaN  KR        NaN    NaN    대한민국
# 48       350        NaN  KR        NaN    NaN    대한민국
# 49       298      02855  KR      서울특별시  서울특별시    대한민국
#
#                                      formattedAddress  crossStreet  \
# 0    [성북구 개운사1길 29, 안암동, 서울특별시, 서울특별시, 136-075, 대한민국]          NaN
# 1   [성북구 보문로30길 71, 동선동, 서울특별시, 서울특별시, 136-052, 대한민국]          NaN
# 2   [성북구 인촌로24길 39, 안암동, 서울특별시, 서울특별시, 136-075, 대한민국]          NaN
# 3            [서울특별시 성북구 안암동, 안암동, 서울특별시, 서울특별시, 대한민국]          NaN
# 4                           [안암동, 서울특별시, 서울특별시, 대한민국]          NaN
# 5                                  [안암동, 서울특별시, 대한민국]          NaN
# 6                [안암동5가 안암로터리, 용신동, 성북구, 서울특별시, 대한민국]          NaN
# 7   [성북구 동선동3가 234-102, 동선동, 서울특별시, 서울특별시, 136-053...          NaN
# 8   [성북구 안암동 고려대학교 백주년기념관 1층, 안암동, 서울특별시, 서울특별시, 대...          NaN
# 9                                         [제기동, 대한민국]         고려대점
# 10  [성북구 안암로 145 고려대학교 백주년기념관 1층 (고대점), 안암동, 서울특별시...          고대점
# 11           [성북구 보문로32길 40, 동선동, 서울특별시, 서울특별시, 대한민국]          NaN
# 12        [성북구 동소문로22길 29-1, 동선동, 서울특별시, 서울특별시, 대한민국]          NaN
# 13                                        [동선동, 대한민국]         성신여대
# 14                                        [종암동, 대한민국]          NaN
# 15  [성북구 동소문로 21-22 5 2층, 3층 (성신여대점), 동선동, 서울특별시, ...        성신여대점
# 16                                        [동선동, 대한민국]          NaN
# 17                            [외대 국제학사 1층, 용신동, 대한민국]          NaN
# 18                [성북구 동소문로20다길 7 (성신여대점), 동선동, 대한민국]        성신여대점
# 19                    [성북구 동소문로 94, 동선동, 서울특별시, 대한민국]          NaN
# 20  [동대문구 정릉천동로 58 (롯데캐슬 피렌체 1층), 용신동, 서울특별시, 서울특별...  롯데캐슬 피렌체 1층
# 21                         [숭인2동, 서울특별시, 서울특별시, 대한민국]          NaN
# 22    [성북구 동소문로2길 43 (삼선교점), 삼선동, 서울특별시, 서울특별시, 대한민국]         삼선교점
# 23  [동대문구 신설동 104-8 진흥빌딩 별관 1 층, 용신동, 서울특별시, 서울특별시...          NaN
# 24                  [인촌로16길 4, 안암동, 성북구, 서울특별시, 대한민국]          NaN
# 25           [동대문구 왕산로 192, 전농1동, 서울특별시, 서울특별시, 대한민국]          NaN
# 26         [성북구 인촌로26길 45-9, 안암동, 서울특별시, 서울특별시, 대한민국]          NaN
# 27                                        [안암동, 대한민국]          NaN
# 28                                        [안암동, 대한민국]          NaN
# 29  [성북구 인촌로27길 25, 안암동, 서울특별시, 서울특별시, 136-075, 대한민국]          NaN
# 30                 [안암동, 서울특별시, 서울특별시, 136-075, 대한민국]          NaN
# 31             [성북구 개운사길 32, 안암동, 서울특별시, 서울특별시, 대한민국]          NaN
# 32                         [성북구 보문로34다길 2, 안암동, 대한민국]          NaN
# 33                [고려대학교 후문 앞, 안암동, 안암동, 서울특별시, 대한민국]   고려대학교 후문 앞
# 34  [성북구 인촌로28길 11, 안암동, 서울특별시, 서울특별시, 136-075, 대한민국]          NaN
# 35         [성북구 인촌로26길 45-5, 안암동, 서울특별시, 서울특별시, 대한민국]          NaN
# 36                                        [안암동, 대한민국]          NaN
# 37                            [동선동, 성북구, 서울특별시, 대한민국]          NaN
# 38     [146-18 (안암동5가), 안암동, 성북구, 서울특별시, 02855, 대한민국]        안암동5가
# 39                                        [안암동, 대한민국]          NaN
# 40           [동대문구 제기동142-2, 안암동, 서울특별시, 서울특별시, 대한민국]          NaN
# 41                           [용신동, 동대문구, 서울특별시, 대한민국]          NaN
# 42                 [안암로9가길 71, 안암동, 성북구, 서울특별시, 대한민국]    안암로9가길 71
# 43                                        [안암동, 대한민국]          NaN
# 44                     [삼선동, 성북구, 서울특별시, 02848, 대한민국]          NaN
# 45                                 [안암오거리, 안암동, 대한민국]          NaN
# 46                          [용신동, 서울특별시, 서울특별시, 대한민국]          NaN
# 47                                        [안암동, 대한민국]          NaN
# 48                                        [안암동, 대한민국]          NaN
# 49                     [안암동, 성북구, 서울특별시, 02855, 대한민국]          NaN
#
#    neighborhood                        id
# 0           NaN  4d0c8964bdbfa35d6e1e6472
# 1           NaN  4bf90093b182c9b69651785a
# 2           NaN  4d88875c4757721e7bc78e69
# 3           NaN  4eccd86902d557995136f91f
# 4           NaN  4df08045227193bb466b7d45
# 5           NaN  51728f29e4b021698a482d88
# 6           NaN  4de9eeb51f6e3ddebdbe878f
# 7           NaN  4db54a1cfa8c350240f5d469
# 8           NaN  4c96d1ff82b56dcb3012e5aa
# 9           NaN  4c7dca54d654370436a4c1a2
# 10          NaN  5160c555e4b0db8cdc7a5be6
# 11          NaN  4c4fd9307537e21ecfabed88
# 12          NaN  4bf1303524f020a1aac8684f
# 13          NaN  4c80764c51ada1cdee560a10
# 14          NaN  4f75ad1fe4b09b101302e88a
# 15          NaN  4f5ec7f2e4b04ddc38f7a07c
# 16          NaN  50c70e48e4b0b612ce994ab0
# 17          NaN  4e92fd1302d5dcbe604e2dc8
# 18          동선동  54fc036f498edf0d9bea98ee
# 19          NaN  4e5f5409ae60c16e993ff806
# 20          NaN  4fbf3394e4b0ed139841fc4d
# 21          NaN  4df5f7266284fefe8fca58db
# 22          NaN  4c7f8015fb74236a6829fab9
# 23          NaN  4ce48d70e860a14334c28da1
# 24          NaN  59a014ddd4cc987933371a9a
# 25          NaN  4d9eef90640b54812a9fd42d
# 26          NaN  4c874b9956e037041425b1a3
# 27          NaN  4cc6822d1e596dcb31e6de67
# 28          NaN  4d900811788c54812db65cfd
# 29          NaN  4c4ac83f42b4d13aeef3b77d
# 30          NaN  5c8638936fd626002ce7fcbb
# 31          NaN  53e5a4bb498ec3e13b542331
# 32          NaN  4eef2bf06da153687c96dbe2
# 33          NaN  51d4e782e4b098c3c4921bc2
# 34          NaN  54bb6cd7498ec690651d9134
# 35          NaN  4c7f792ba7958cfac8b6902b
# 36          NaN  4d296375b818a35dd6a89e8a
# 37          동선동  597d928035dfa72979489b48
# 38          NaN  5a2de00bda5ede1661ccad83
# 39          NaN  58bfc94137318118df1d8463
# 40          NaN  4de335511f6e3190cd230519
# 41          NaN  596424eaa2c00b527a8f18da
# 42          NaN  59b7a96e898bdc4e5fccdc45
# 43          NaN  52e351c211d253c59c85a570
# 44          NaN  5a082dbf6bd36b49e5b39ffe
# 45          NaN  512ca042e4b0e4a8799178d4
# 46          NaN  4e898860550364195b9c07a5
# 47          NaN  4c01e53027dcc928505ae152
# 48          NaN  4cc8ba61e7926dcbeaf55777
# 49          NaN  5a5b1be9336273355f568774

# %% [markdown]
# So the cafes around Korea University is..

# %%
for lat, lng, name in zip(koruniv_filtered.lat, koruniv_filtered.lng, koruniv_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=name,
        fill = False,
    ).add_to(map_Koruniv)

map_Koruniv
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Analysis

# %% [markdown]
# Each cafes around the areas should be assessed differently. So I will score each cafes' location based on their distance from the center. The closer they are, the higher score they will get, so that the place with lower total score could mean that they are less crowded with cafes nearby and it will be the optimum location to open a cafe.

# %%
sogang_distance = np.zeros(sogang_filtered.shape[0])
sogang_score = np.zeros(sogang_filtered.shape[0])
sogang_score_accu = 0

# %%
for i in range(sogang_filtered.shape[0]):
    xy = lat_lng_to_xy(sogang_filtered.iloc[i, 3], sogang_filtered.iloc[i, 4])
    x2 = xy[0]
    y2 = xy[1]
    sogang_distance[i] = xy_distance(Sogang_x, x2, Sogang_y, y2)
    if sogang_distance[i]<500:
        sogang_score[i]=3
    elif sogang_distance[i]<1000:
        sogang_score[i]=2
    else:
        sogang_score[i]=1
    sogang_score_accu += sogang_score[i]

# %%
sogang_score_accu
# Out:
# 92.0

# %% [markdown]
# ### It turned out that locations score for Sogang university is 92.0
#
# Then how about Korea university?

# %%
koruniv_distance = np.zeros(koruniv_filtered.shape[0])
koruniv_score = np.zeros(koruniv_filtered.shape[0])
koruniv_score_accu = 0

# %%
for i in range(koruniv_filtered.shape[0]):
    xy = lat_lng_to_xy(koruniv_filtered.iloc[i, 3], koruniv_filtered.iloc[i, 4])
    x2 = xy[0]
    y2 = xy[1]
    koruniv_distance[i] = xy_distance(Koruniv_x, x2, Koruniv_y, y2)
    if koruniv_distance[i]<500:
        koruniv_score[i]=3
    elif koruniv_distance[i]<1000:
        koruniv_score[i]=2
    else:
        koruniv_score[i]=1
    koruniv_score_accu += koruniv_score[i]

# %%
koruniv_score_accu
# Out:
# 110.0

# %% [markdown]
# # Results

# %% [markdown]
# Sogang university got 92 while Korea university 110. It means that Sogang university is less crowded with cafes nearby

# %%
pd.DataFrame(np.array([[sogang_score_accu, koruniv_score_accu]]), columns = ['Sogang Univ', 'Korea Univ'])
# Out:
#    Sogang Univ  Korea Univ
# 0         92.0       110.0

# %% [markdown]
# # Discussion & Conclusion

# %% [markdown]
# In my analysis, it turned out that Sogang university is better place to open a cafe, rather than Korea university based on the score drawn out as above
